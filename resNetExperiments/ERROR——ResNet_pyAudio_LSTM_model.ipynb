# %%
train_dataset_dir = '/home/noa_glaser/dataBig/train-1-2-3-4/train'
val_dataset_dir = '/home/noa_glaser/dataBig/train-1-2-3-4/val'
audio_dataset_dir = '/home/noa_glaser/dataBig/train-1-2-4-audio'
label_dataset_dir = train_dataset_dir
exp_name = 'ResNet34_LSTM_experiment' # roughly 3K videos
num_classes = 5 
num_partition = 10
batch_size = 8

# %%
# -*- coding: utf-8 -*- 

from __future__ import print_function, division

import pickle
import sys

import os
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable
import numpy as np
import torchvision
from torchvision import datasets, models, transforms
import torch.utils.data as data
import matplotlib.pyplot as plt
# %matplotlib inline


from PIL import Image
import time
import copy
import shutil

# %% [markdown]
# ## first, get the Images (path) and their labels (five personality traits)

# %%
def get_img_audio_label(dataset_dir,audio_dataset_dir,label_dataset_dir):
    """Returns a list of np.array(img_paths), np.array(audio_paths),np.array(labels), np.array(raw_movienames)
    Args:
    dataset for video, for audio_feats from pyAudioAnalysis, labels
    """
 
    print("processing dataset: "+ dataset_dir)
    img_paths = [] 
    audio_paths=[]
    raw_movienames = []
    labels = []

    annotaion_filename = label_dataset_dir + "/annotation_training.pkl"
    
    with open(annotaion_filename, 'rb') as f:
        label_dicts = pickle.load(f, encoding='latin1') 

    for movie in os.listdir(dataset_dir):
        fileEnding ='_50uniform' #TODO: figure out how to make more general
        if fileEnding not in movie: continue #skip non-movie files
        raw_moviename = movie.replace(fileEnding,'.mp4')
        
        
        big_five = [label_dicts['extraversion'][raw_moviename], 
                    label_dicts['neuroticism'][raw_moviename],
                    label_dicts['agreeableness'][raw_moviename],
                    label_dicts['conscientiousness'][raw_moviename],
                    label_dicts['openness'][raw_moviename] ]
                    #label_dicts['interview'][raw_moviename]]
        
        
        
        
        movie_path = os.path.join(dataset_dir, movie)
        mv_partitions = []
        p = 0
        all_imgs = os.listdir(movie_path)
        assert(len(all_imgs) >= num_partition)
        
        opened = True
        for i in range(num_partition):
            path = os.path.join(movie_path, all_imgs[i])
            try:
                open(path)
            except:
                print('image failed to open',path)
                opened = False
                
            mv_partitions.append(path)
        assert(len(mv_partitions)==num_partition)
        
        
        audiofeat_path = os.path.join(audio_dataset_dir,raw_moviename+'.wav.csv')
        try:
            open(audiofeat_path)
        except:
            print('audio failed to open',path)
            opened = False
        
        
        if opened :
            img_paths.append(mv_partitions)
            audio_paths.append(audiofeat_path)
            raw_movienames.append(raw_moviename)
            labels.append(big_five)
            
    
    return np.array(img_paths), np.array(audio_paths),np.array(labels), np.array(raw_movienames)

# %% [markdown]
# ## use this if we need to split our dataset into train/val

# %%
#all_img_names, all_labels, all_movies = _get_imgname_and_moviename_and_labels( dataset_dir)  
#validation_size = 0.3
#num_validation = int(validation_size * len(all_img_names))

#all_img_names = np.array(all_img_names)
#all_labels = np.array(all_labels)
#all_movies = np.array(all_movies)
#training_filenames = all_img_names[num_validation:]
#validation_filenames = all_img_names[:num_validation]
#train_labels = all_labels[num_validation:]
#val_labels = all_labels[:num_validation]
#train_movies = all_movies[num_validation:]
#val_movies = all_movies[:num_validation]

# %% [markdown]
# ## use this if we have seperated train/val dataset

# %%
train_img_paths,train_audio_paths, train_labels, train_movienames = get_img_audio_label(train_dataset_dir,audio_dataset_dir,label_dataset_dir)  
val_img_paths,val_audio_paths, val_labels, val_movienames = get_img_audio_label(val_dataset_dir,audio_dataset_dir,label_dataset_dir)
# Out:
# processing dataset: /home/noa_glaser/dataBig/train-1-2-3-4/train
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/4lIbWq27O84.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1dOaM7zWPo8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/do8FmnQbI5I.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-aU2FN5pkWA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/aqd4_4ga1fQ.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/lvae9lRUugE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EjhDyc8Oc6k.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/KNOHhnRMpSw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kzDQXSGGomg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ua5c716lu5s.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DxATjKPysfs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LKvxVEI8uVA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mflgXFsGU9w.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/4lj66h4CXI8.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/13XlKeC_p3U.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8RVJqjILSD0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/RbX4q4KceVk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/l8weBJSCHbA.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6-O-HJf6OZI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/b6eoqD1J_qU.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tutTFKP_fdg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/auhe41Tf50M.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/upgv7xmOb1I.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GkPz3-y6Les.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/si_gZCrLa4A.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YzcZY1mUZfc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DnTtbAR_Qyw.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/PHmkN1cPl10.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7nhJXn9PI0I.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/sSYCMN-WHmI.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3yU-7AXnFCM.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2mgj9ncREyA.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/V1TjmLtgNm0.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qfL0ml0f84g.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TQHzCznQ14Y.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/uTluOTPA7e4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/59Smv7wl--w.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/nClvfVFYzbM.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mkWfG-4vvGc.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Lt89YrQHF_w.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5CRqN54uejE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tBQlU4_cIS0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/IL5VgGakSNw.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HoJXPFp9hYo.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9xJ0rFCU-OM.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Y2An1KkoHzY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LWylAwr9kJI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8pM3X-xsD4s.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/THO-md3eEkA.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/_X6_C_Oy9VA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/g4PQ753TDls.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/l-WgXcGLdZk.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fsaslN7xV-w.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Qkao4XiSflU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/gkKHdsF6du4.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/dy9EqbKLDP0.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xgwiqo2AsCA.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Jp-Hu7yxqR8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YryBLVZgJj0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HNKnvSmTkC4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mkWfG-4vvGc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tNPLxKC38Xs.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MI_GQLbnoew.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/p6UMx8dwHZQ.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-c2HtptBFxY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/G2D3qU6R_YA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5Eez38v8TuU.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/PVm7Om88BSw.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/PKtzsEqLGx4.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/OuE91U_n04E.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vQEZ5KF9I4E.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/outvbZgNX58.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/jjFzwsootdM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/yRVvI1x2DBI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/gj3-xvhPeWg.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bZAKBS9q0ZI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6ePyEPQp77Q.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fhUGU2uiS1U.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/hG0I7DLSSYg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Pb9GhzCRnqs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/BjzSIV3dutk.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ecIb16gJMwU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MK7KveAeb6Y.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/12Hbl_oZF9c.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-IK--4uz5ZY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/53QFyec0uN0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/KLY518hfGhU.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/opqoflph5ZE.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7TvOygqwNuE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Gs-AdRcYSPo.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/XLV7teADu3c.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/glgfB3vFewc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/b-qfeGqPd04.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bcRPLKygrNk.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9Crw2RtrBcY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tGHOYmQHZUc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VZ6jhnbk-5g.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/XcEFSi3uaJM.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/f7togdqxEoo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/N1ZOAktFbI0.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Vd9biSOZ5CI.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/JEualxMkaE4.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/rrdSLfnU2pg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/F4UeAogUMMs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9cj8rrj1wSk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Vy-Lr_iM5qo.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DiaibIBisuM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/x0CZuHnJ0Hs.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0kg6pmbSN6A.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0ZK5jQAvhFo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/K7vBdKrcFKo.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9mAw0B-mEPQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YPnuq0tDDqk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/s3m8DgUi6GM.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EknEAPhAjdA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qBG1mjC7Zgg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/k1eXxMAfnIY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9CPKW0sqR3E.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/p6UMx8dwHZQ.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FaBTYkzhuK4.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/AFtQfwBA_gI.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qAisk1lgv2I.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9J-KIPMQmqk.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GG9WPQLI_rg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LCafv-LfC3Y.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/pOtWKOF07iU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CQMH9Qguuao.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/M_OpMKBEOyU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2oiXF5_gTyk.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/uNJpPYo5Qp4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/uTluOTPA7e4.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/F5kL7RWS_f0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DChmTb-c9uM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/S-jhg6Y5OrE.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9rF3BEXetOo.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/OMHlfDF99Mw.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qktahyrtrFs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MLCIfM5jYlI.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/frsDpQjmC5k.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/G2D3qU6R_YA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3HA2W1s4oP8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-Gl98Jn45Fs.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/lxnV9X8T2Zc.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vIW7gDmhYMk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5kwoq4EZixQ.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VIhStXxpAr0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-Gl98Jn45Fs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/98fnGDVky00.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/c7tczvW3_dQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MT3tOBpG5II.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/utv9RBNcL5w.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/S0QIXcQGG-g.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xZFZ0Mvjiuo.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2TMl5EMrdVI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YXz6s1XNOLs.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mnRuiwFx_Z8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/RDOngWykAQU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-6otZ7M-Mro.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/taSAaWKcmTw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/I5x9T9ftW18.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/b39BQbVhOAg.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/squHxV3QXlQ.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kare8QF7vrE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/eXtskPoi58A.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8RVJqjILSD0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LqtBNNM2jIw.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mQpNe8f5xA8.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/dQOeQYWIgm8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5BPGRteF64Y.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EX3i4IMY1Pw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HoJXPFp9hYo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FM5UaJS-bhg.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fDw_PAgW07o.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bcRPLKygrNk.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Ie2y_yOeKpo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EDshSjcCsoY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LCafv-LfC3Y.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TiQF5QduRNE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CqQavmWSLrI.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/pDt0F4zFfBs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/WD1WsbooU2w.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-fXqnCljdm0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/cuyIFvYNLFE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7UQt8QB3cQY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/jwcSbw4NDn0.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Z3FdUfZLHyw.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/hG-pwa191bw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GS7cBLgZKgk.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ox-qZvCLtls.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6nv6D2moFQw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TNjEJGdqmH0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/r1YAW67aevY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/wTo1uZns2X8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/k4eeYoHtnnI.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/OZlpENU9h28.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9CPKW0sqR3E.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vUo6wnBOBpo.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bnoPmV0_aIc.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ZT7cEiaYGp8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0MB91ku0eEw.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Dq7Uep06KOQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DvmzcQI5cnM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/RbX4q4KceVk.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5IqtX-uq28E.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5Bgd2zgiT0Q.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/RZgTERiRDjA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/z3DO3tdrsnQ.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/taSAaWKcmTw.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/KXUERmhPyr8.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Jr6GmDtvTK0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/rGTn2uaCAT0.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/K63T9l1xY7U.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VRjJxTqOJyo.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/J28DwJsK8Do.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vLAHfIjmRMc.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Zvdh8ym1Yrg.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YuoLr4xDvbE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/BS0wgLXqFgc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/dOFnHXRLEdM.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/j5fXaXrNPoA.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Qqc1539E6rs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Kv0kZgqZEM0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/sRuO_Fz3eog.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GUxm9AWVpOI.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/04oq2yrBwMg.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VZ6jhnbk-5g.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/twmdh5zdvfg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/IHJn3UHXCMs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VIhStXxpAr0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TmyDT-HC3qI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8n6G3V3-Tk8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/cT3oyHhUznw.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Lq4uvcHNiy8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/dRr2JtdzUpU.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TPk6KiHuPag.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FksSYDfLH04.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0_xOGmydDN0.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/XvV4YdhpC2w.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/okdZnQbLnf8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/QKcx5msA7iA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/U2RemWUyjts.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/nOCSTnpB_F4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/aJjAtOC8AQU.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3gKpBq-1yG4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ng42eoHytOA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-RhPxhfpg4U.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2UqnC_rFcRQ.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MK7KveAeb6Y.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/zF46tAI2PQc.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/geji1U2YAvg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mpXOSY5dW7c.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xP6i_WO1LCM.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kAjvzIWWrWA.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/o0zIPrIQY4o.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GQczMGrVgbc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CRLsCyMfskE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/M0U48Lm33A8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/QS7TwjzkYiU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kwcpINU9LLk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3nxH1f6IQjQ.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/81f9t2HMNas.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7wsksuXYoMY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/A0braVJH3Pw.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/SPpox8EGQqU.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Cl7vQ9QR0es.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/dvMeqVbpKW8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FoWuHvikyqU.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/shAhNNV-zHA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tvKUJujTUEo.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Tch2Bt9b8AY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/eFzN_frNW8g.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/eI_7SimPnnQ.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/A0braVJH3Pw.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/y0UCXXk9tlM.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9yZEb6bdxNY.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7nJPNkWZDOY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6h6kk-tPzmE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HX-3jJdK7HM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1Lv72Si4GnY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/oBE9f5xD9rk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8PXQ_5tUv74.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qBG1mjC7Zgg.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/SI93csgHMTk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/keGXYAcUXmA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/m2uxFfpb5xU.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HCkDd0UnUgo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FNHMXPaHll0.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/yrToGVRf27U.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0zJcYnsh55g.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/oqXx6ipHfUE.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/m4KKYcD6CZw.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/cvg03XGFjCk.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xzRYaxrhne8.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LBrmHHzyIiY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3ySH8eJQRCI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/eRRCer7epnA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ASDpn9yOYAo.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0VnZngec8sc.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/n6JNJurop2U.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/44rxmXiga90.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/zeUC7e-4w1E.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/PtA7yAu9-VE.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/TNjEJGdqmH0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2TbU3Eg2i4A.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-c_tyGzShwk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/JFKZEGDhcRs.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Fi1ILrwQpSY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/GS7cBLgZKgk.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/r1v6EmZv7-o.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2uAJJH7B5aw.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xpSCu7PgJts.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/41NNb7cucVo.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/l3RE0rN7oEg.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-N6QKrbnaDs.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Gd08FYfFRtk.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YXz6s1XNOLs.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bZoN9xp9vgs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/j3jdT1V-DeI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Etw3iulV5Eg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8bn3HZY76xU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YzcZY1mUZfc.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xgRqkTXmZko.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ywefrPdzz0U.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Fe9_SVPd_5I.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/iqs7mZbg5UI.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/geXpIfaFzF4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8PXQ_5tUv74.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/yftfxiDNXko.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/FGkS4vJYOpM.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EwMMNKLjO9w.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Y1LrgyCJtpU.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/F4UeAogUMMs.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/oXRhk1PUPcQ.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/aoRjg63uRww.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/i1gouUmZumY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/4VwcU0ROy5k.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1tPH6PNeOSk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/NG8qWulkRM4.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/VjYqagJ4xt8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/4bDOetaLvZs.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3tPq9fNOXZQ.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vUKex2msIEU.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xeE08Vn-HXI.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/iOB65zCiOFM.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CCe1J5grs8U.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/bmj4khBLUOs.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ciWUq6iQTIE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/uwUkp63db18.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CESTtNvDpww.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qPzzmcuf-VI.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/zrbcY4TMVyc.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/CFk4v2Kd5Ns.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Pr-RpZ4gYCM.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/65xWDhgq1OE.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3GylAjrajHs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/L5kpy0SA7os.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LNM1i-a9q_A.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/b8GPFr11adA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/A1lbD_OCuj4.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ADa9rkwF2uA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/5Wfa94_5Psg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/WT1YjeADatU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/M56UFrEgXnI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YC3X1DcnUrk.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/opyTSeVCYtE.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/DXw4lVoiiWY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9n8dNi-ERQ0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7GRC7XjGzX8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YuoLr4xDvbE.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/-Osv5l1vrNU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mpXOSY5dW7c.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/cgp1OzTOq1o.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/jolhoLhAurM.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/KfurkMyjD-c.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1-GgVRmAEoo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/JZNMxa3OKHY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/yFZ3eUD6Pqs.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/YPMffqhP0C8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3ccY8jYkI5o.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/orlXEgAepGo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/XT4rTk6-Etc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ask-ZFRztf8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/htH89DBizno.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ga_XczsO4eY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/OZaP2T74bLI.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/RWfY3Xk0XPQ.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/4lj66h4CXI8.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/7LHmNEH65Pk.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1UaqZEUUk9I.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/0iQIfGnKflc.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Gdrgw7Z6tLg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ev42vngXERU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/m4KKYcD6CZw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/P9WDAY-MFzk.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fyXiORXmWHs.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/a97PXgrKSxo.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fEC3lEDxRnc.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Ry5JJvTfP-8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ihA8DzHWyiU.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LsPKxJgefks.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/19cplBTXyoY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6wHQsN5g2RM.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/LXmwDq89LdA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9kEyN8a76j4.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/176vWywoq9E.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/nR0h3WFbPfA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/nQxTTYWy7pA.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/tS6bRcIIjDc.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/O3_j0d7mq7k.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/isqmQc9AfBc.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/SgWtBK48AjE.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Y8gv_ZK3w4A.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/3LAaFUSGvsU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/ZGox7tevC6A.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/aFVFvJNnFt0.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kDJigDGDJTo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/KpTHRBaYny8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fTpemcfElxI.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kX-o1qmgWvc.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/lkdQjIunxSE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/x57nEfACdXA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/zJEnT19uoPY.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/m04e9ylCoK0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/d4cPiUXpGbc.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/OeT6Skotv7g.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/o2wtRccAgjE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/qW0TYVtzq5A.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/U3UaF1aFek4.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/UA6UY69EVSI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xsLvl2qGrxU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/36NZ0sHWQFg.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/m4-vvEeWP8s.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/AJIphVRpYrg.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mXaI17Dx7u0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/A3StIKMjn4k.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/izq1ogkfedI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/_fJcW5234bY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/G7hYffrZ1Hc.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/6e5BsNaQmTo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/EYbPGTIcnjs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/9RfE2-aTvaM.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/2fzLibPAtvI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/xzRYaxrhne8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/UipoC_HLOP0.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HTF8k56_Oxo.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/kp3c66Igyr8.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/SBEad3L1Hdc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vhugKRUnd-c.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/MrfJ1qDJAwo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/1q-N_zbsAg0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Lj1WuMXFa-4.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/mZQP06F94u8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/J30sMEMrKjA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/wYZJ2HXfvmQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/UipoC_HLOP0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/83cmR2fkyy8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/XOioICna1hc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/QovE6L-C9VY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/8waTw8jF1Ys.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/l-WgXcGLdZk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/HbGeoKBULAA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/lLObIVKYDUI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/vNZJSHliTR4.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/Cvuu76B-bxA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/train/fkDqn2muw-A.003_50uniform/frame0.jpg
# ...
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/nCWEEoJfjgE.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/gipWTZy9mjI.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Lz3hYPF6aIM.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/VtYPH6UsVnU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/2TXrDZgbDHE.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/syAUKJMQWeo.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/m7zdWVDT-34.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/UANQntvIqVk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/90p68AEmNMA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/twO6ceVTuII.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/k2buv6xZ4_o.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ksCoS_ghDfM.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/3Q3SB1dVAng.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ZNJFmNiWC4I.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/y6LC5kAJmHw.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/r9TaaVTo8Y8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/6uqXoPJSoPg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/zxuPCshTSOs.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Qu81v9Aybv4.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/tepWDnvIuRg.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/bMY2DaFFwzU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/eD4b8sM-Tpw.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/nndDX4RgU1w.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/6ePyEPQp77Q.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/HPEemWelY1E.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Jv2lyDcOmEM.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/8XJCdulCPkM.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/c5ZnKbaNCE8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/-fXqnCljdm0.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/HkBs4_vaCcs.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Bk9Hxn7Drxw.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/U_QQ8EuuWPg.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/nskJh7v6v1U.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/O14mSiNfYDo.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/merppcmY6y0.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/2WuhWF4fAOQ.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/mIQnQ8Nmj-c.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/lNY0BdE4NqY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/IFF47jVKMj8.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/do8FmnQbI5I.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/AR3UwbmgKuQ.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/DXw4lVoiiWY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/mKWscEow1U8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/4JYmE9a21aI.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/iW1t-ZiG2rc.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/9cj8rrj1wSk.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/8-OKP1nf19E.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/vJDx6TCX32M.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jSw-grsJCnE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/I53JQFtiQxM.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jSw-grsJCnE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/cRDYrvxRJ6U.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/vCY4uvfrWXA.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/81f9t2HMNas.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/yzgA9oAEgI4.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/LeuT6NgJ6N8.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/vHIBCKwJLEY.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/3zAyM2edy1g.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/mIQnQ8Nmj-c.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/zNmuwZkaeVg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/29UCGJldICw.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/kDXYolv-8p8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ana5C73n9bY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/CpmR-91GxmY.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/FM5UaJS-bhg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/4V7doeEKsus.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/3ySH8eJQRCI.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Bz3Jx4QL_6Q.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/kSk-rf7a1Ig.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/txU8yE9d-4k.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/nKLhatlbqEw.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/kppgmuWEv-A.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/FrOxqNe6sAU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/KahSwziq8F0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/70FJFG-MISQ.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/nskJh7v6v1U.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/dY7jG5gS3JE.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/TwWDFpN3occ.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jnEHHvlBgxE.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/SOxdUtjGmAo.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/gkKHdsF6du4.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/geXpIfaFzF4.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/luH2RoZW-eY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ROTx-0q1F9M.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/mnRuiwFx_Z8.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/qLbOPbx33dk.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/YbdJd16c3eo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/1RMdiCbNNh4.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/sOkGz6gEmGk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ana5C73n9bY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Cvuu76B-bxA.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/V7_h3URfSFY.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/d5ujzxBlvwY.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/KD9rExmTXcE.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/sntohi33U5s.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/CQMH9Qguuao.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/rGNeR3p1jKU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/XQZ5M9oLkXw.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/cgp1OzTOq1o.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/WuoQDp7pU24.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/CPtaCNonKlE.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/B4ducm9sydg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/s6gN_358tk4.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/KM6Nc_VipyQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ev42vngXERU.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/TNjEJGdqmH0.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Bo-mrL28d8M.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ai-RZb0ZpKI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/fkDqn2muw-A.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/U-PRay-woXU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/EknEAPhAjdA.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/isqmQc9AfBc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/PooFvZH6fK0.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jxt1W2WRNHQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/1mODTfLRGdI.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/kN9cs2nFhM4.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/57RdMTGegww.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Vd9biSOZ5CI.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/f8f00b0IgvA.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/cgGCyBMdGrA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jmbAPNTJ3Vk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/GUxm9AWVpOI.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/fPLd_NLF43M.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/R_LJX7wszPY.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/HT_8WpgGqjk.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/HT_8WpgGqjk.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/qtB-CogljAo.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/CFk4v2Kd5Ns.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/jpRnHWTLDUs.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/eZwGkhUa0TQ.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/hmTY4CubpiE.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/odHogR_36Dc.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/3LAaFUSGvsU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/ZCLfVue6xAg.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/KnbEca4Ibwk.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/8bn3HZY76xU.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/WUNXs4r_xCU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/J0JrzUmZGcA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/bAxlTgobVHE.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/HONL8ha-1BE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/VUgKH9DIs-8.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Ya9Szm73LfE.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/G-25EWOIGNs.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/OdwK_oMdfSU.003_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/Wy4hWbeibhU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/XhgDsQlEnuU.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/RGuHfwIRKpA.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/_G3kw9HwCqY.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/DLds0WJpIQg.001_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/5ghk5950BhU.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/YN0Xd70SqEo.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/YjXUMygVw7U.002_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/dVbo9Ftlyl0.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/LRczShwIVbM.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/FwjoTGcsFNg.000_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/LGdzP-r_G3U.004_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/iOv0_RdVPCM.005_50uniform/frame0.jpg
# audio failed to open /home/noa_glaser/dataBig/train-1-2-3-4/val/w7wPDiQkiA4.001_50uniform/frame0.jpg

# %%
len(train_img_paths),len(train_audio_paths),len( train_labels),len( train_movienames)
# Out:
# (2304, 2304, 2304, 2304)

# %% [markdown]
# ## Data Loader. Data is normalized before feeding into model (as required by the pretrained model)

# %%
def default_img_loader(img_paths,transform):
    ten_img_tensor = []
    for path in img_paths:
        img = Image.open(path).convert('RGB')
        if transform is not None:
            img = transform(img)
        ten_img_tensor.append(img)
        
    return torch.cat(ten_img_tensor)
        

def default_audio_loader(path):
	return np.loadtxt(path,delimiter=',')

class VisualAudio(data.Dataset):
    def __init__(self,split,img_paths,audio_paths, movie_names,labels,transform=None,
                 img_loader=default_img_loader,audio_loader=default_audio_loader):
        if len(img_paths) != len(audio_paths) or len(audio_paths) == 0 or len(labels)!=len(audio_paths) :
            raise(RuntimeError("something is wrong with the data directory"))
                  
        self.split = split 
        self.img_paths = img_paths
        self.audio_paths = audio_paths
        self.movie_names = movie_names
        self.labels = labels
        self.transform = transform
        self.img_loader=img_loader
        self.audio_loader= audio_loader
        
    def __getitem__(self, index):
        img_paths, audio_paths,target = self.img_paths[index], self.audio_paths[index], self.labels[index]
        ten_img_tensor = self.img_loader(img_paths,self.transform)
        ten_audio = self.audio_loader(audio_paths)
        #return 30x224x224 , 10x68, 10 x 5
        
        assert(ten_img_tensor.size() == (30,256,256))
        
        return ten_img_tensor, ten_audio[:10,:], target

    def __len__(self):
        return len(self.img_paths)

# %%
from torchvision import  transforms

data_transforms = {
    'train': transforms.Compose([
        transforms.Scale(256),
        transforms.RandomCrop(256),
        #transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val': transforms.Compose([
        transforms.Scale(256),
        transforms.CenterCrop(256),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

        
dsets = {}
dsets['train'] = VisualAudio('train',train_img_paths,train_audio_paths,  train_movienames ,train_labels,transform=data_transforms['train'] )
dsets['val'] = VisualAudio('val',val_img_paths,val_audio_paths,val_movienames,val_labels,transform=data_transforms['val'] )

dset_loaders = {x: torch.utils.data.DataLoader(dsets[x], batch_size=batch_size,
                                               shuffle=True, num_workers=1) for x in ['train', 'val']}
dset_sizes = {x: len(dsets[x]) for x in ['train', 'val']}
dset_sizes
# Out:
# {'train': 2304, 'val': 576}

# %% [markdown]
# ##  Some dataset examples (each batch is 16)

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


#train_imgsamples,train_audiosamle,train_labelsample = next(iter(dset_loaders['train']))


#train_unflattened_sample = train_imgsamples.view(-1,3,256,256)
# Make a grid from batch
#plt.figure( figsize=(10, 16))
#out = torchvision.utils.make_grid(train_unflattened_sample,nrow=10)
#imshow(out, title='trainning sample')
#plt.savefig('train_exp.png', bbox_inches='tight')

# %%
#val_imgsamples,val_audiosamle,val_labelsample = next(iter(dset_loaders['val']))
#val_unflattened_sample = val_imgsamples.view(-1,3,256,256)
### Make a grid from val batch
#plt.figure( figsize=(10, 16))
#out2 = torchvision.utils.make_grid(val_unflattened_sample,nrow=10)
#imshow(out2, title='validation sample')
#plt.savefig('val_exp.png', bbox_inches='tight')

# %%
# some gpu configs
use_gpu = True
gpu_dtype = torch.cuda.FloatTensor

# %%
class AverageMeter(object):
    """Computes and stores the average and current value"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

def save_checkpoint(state, is_best, filename='checkpoint.pth.tar'):
    """Saves checkpoint to disk"""
    directory = "resnet_for_rnn/%s/"%(exp_name)
    if not os.path.exists(directory):
        os.makedirs(directory)
    filename = directory + filename
    torch.save(state, filename)
    if is_best:
        shutil.copyfile(filename, 'resnet_for_rnn/%s/'%(exp_name) + 'model_best.pth.tar')

def log_value(to_log, log_path = './log_'+ exp_name + '.txt'):
    log_file = open(log_path, 'a+')
    log_file.write(to_log)
    log_file.close()

# %%
#train_model(startModel=None, startEpoch=0, numEpochs=5)

# %%
def get_learnable_params(m,verbose = 0):
    ret = []
    for l in m.parameters():
        if l.requires_grad == True:
            ret.append(l)
            if verbose == 1:
                print (l.size())
            if verbose == 2:
                print (l)
    return ret

# %%
#p = get_learnable_params(model_base,1)

# %% [markdown]
# ## verify only the last fc layers params are being optimized

# %% [markdown]
# ## Train The Model

# %% [markdown]
# ### some helper functions

# %% [markdown]
# ## train and eval functions

# %%
log_freq = 10

def train(train_loader, model, criterion, optimizer, epoch) :
    batch_time = AverageMeter()
    losses = AverageMeter()

    # switch to train mode
    model.train()

    end = time.time()
    for i, data in enumerate(train_loader):
        # measure data loading time
        input_image,input_audio, target = data
        input_image_var, input_audio_var,target_var = Variable(input_image.type(gpu_dtype)), \
            Variable(input_audio.type(gpu_dtype)),Variable(target.type(gpu_dtype))
        # compute output
        output = model([input_image_var,input_audio_var])
        loss = criterion(output, target_var)
        # measure accuracy and record loss
        losses.update(loss.data[0], input_image.size(0))
        # compute gradient and do Adam step
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if i % log_freq == 0:
            to_log = 'Epoch: [{0}][{1}/{2}]\t Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t Loss {loss.val:f} ({loss.avg:f})\n'.format(
                   epoch, i, len(train_loader), batch_time=batch_time, loss=losses)
            log_value(to_log)
            print(to_log)
            
       
    return losses.avg


def validate(val_loader, model, criterion, epoch):
    """Perform validation on the validation set"""
    batch_time = AverageMeter()
    losses = AverageMeter()
    # switch to evaluate mode
    model.eval()

    end = time.time()
    for i, data in enumerate(val_loader):
        input_image,input_audio, target = data
        input_image_var, input_audio_var,target_var = Variable(input_image.type(gpu_dtype)), \
        Variable(input_audio.type(gpu_dtype)),Variable(target.type(gpu_dtype))
        # compute output
        output = model([input_image_var,input_audio_var])
        loss = criterion(output, target_var)
        # measure accuracy and record loss
        losses.update(loss.data[0], input_image.size(0))
        # measure elapsed time
        batch_time.update(time.time() - end)
        end = time.time()
        if i %  log_freq == 0:
            to_log = 'Val/Test: [{0}/{1}]\t Time {batch_time.val:.3f} ({batch_time.avg:.3f})\t Loss {loss.val:f} ({loss.avg:f})\n'.format(
                      i, len(val_loader), batch_time=batch_time, loss=losses)
            log_value(to_log)
            #print(to_log)
                        
    return losses.avg,input_image,target,output

def train_model(startModel=None, startEpoch=0, numEpochs=10):    
    model = AudioVisualLSTM().type(gpu_dtype)
    #del model_base

    #  changed to l1 loss to reflect competition 
    criterion = nn.L1Loss().type(gpu_dtype)

    #only optimizing the new_fc layer parameters, other pretrained weights are freezed¶
    optimizer  = optim.SGD(get_learnable_params(model),lr=5e-2, momentum=0.9,weight_decay=5e-4)

    best_loss = 1000 # will get overwritten
    
    if(startModel != None):
        print("=> loading checkpoint '{}'".format(startModel))
        checkpoint = torch.load(startModel)
        startEpoch = checkpoint['epoch']
        best_loss = checkpoint['best_loss'] # for now because old loss is stale
        model.load_state_dict(checkpoint['state_dict'])
        # todo - figure out why not working
        #optimizer.load_state_dict(checkpoint['optimizer'])
        # print(optimizer.param_groups)
        
        print("=> loaded checkpoint '{}' (epoch {})"
              .format(startModel, checkpoint['epoch']))
    #else:
        # benchmark the model 
        #best_loss = validate(dset_loaders['val'], model, criterion, startEpoch)
        
    bestModel = model

    for epoch in range(startEpoch,startEpoch+numEpochs):
        # train for one epoch
        train_loss = train(dset_loaders['train'], model, criterion, optimizer, epoch)

        # evaluate on validation set
        val_loss = validate(dset_loaders['val'], model, criterion, epoch)

        # log 
        log_value('Epoch: [{0}]\t Train Loss: {train_loss:f}  \t Val Loss: {val_loss:f}\n'.format(epoch,train_loss=train_loss,val_loss=val_loss) ,'./epoch_log.txt')
        print('Epoch: [{0}]\t Train Loss: {train_loss:f}  \t Val Loss: {val_loss:f}\n'.format(epoch,train_loss=train_loss,val_loss=val_loss) ,'./epoch_log.txt')

        # remember best loss and save checkpoint
        is_best = val_loss <= best_loss
        best_loss = min(val_loss, best_loss)
        save_checkpoint({
            'epoch': epoch + 1,
            'arch': 'resnet34_lstm',
            'state_dict': model.state_dict(),
            'best_loss': best_loss,
            'optimizer' : optimizer.state_dict(),
        }, is_best)
        print (is_best, best_loss)

    print ('Best Loss: ', best_loss)

# TODO: for larger dataset, consider a step function or exponentialdecay
def lr_scheduler(optimizer, epoch):
    return optimizer

# %%
class AudioVisualLSTM(nn.Module):
    NUM_VID_FEATURES = 128
    NUM_AUDIO_FEATURES = 32
    NUM_LSTM_HIDDEN = 128
    NUM_PARTITIONS = 10
    NUM_CLASS = 5
    
    
    
    def __init__(self):        
        super(AudioVisualLSTM, self).__init__()
        self.audioBranch =  nn.Sequential(nn.Linear(68,32))
        self.videoBranch = self._createVideoBranch()
        
        self.lstm = nn.LSTM(
            input_size=(self.NUM_VID_FEATURES+self.NUM_AUDIO_FEATURES),
            hidden_size=self.NUM_LSTM_HIDDEN,
            num_layers=1,
            bias=True,
            batch_first=True # input and output tensors provided as (batch, seq, feature)
            # can add dropout later
            )
        self.fc = nn.Linear(self.NUM_LSTM_HIDDEN,self.NUM_CLASS)
        self.sigmoid = nn.Sigmoid()

    def _createVideoBranch(self):
        #return nn.Linear(256,1024)
        model_pretrained = torchvision.models.resnet34(pretrained=True)
        # All of the parameters are freezed, not to change (newly constructed layers' params won't be influenced)
        for param in model_pretrained.parameters():
            param.requires_grad = False   
        model_pretrained.fc = nn.Linear(model_pretrained.fc.in_features, self.NUM_VID_FEATURES)
        return model_pretrained
    
    def forward(self, x):
        N=8
        P=10
        videoData = x[0].view(N*P,3,256,256)
        audioData = x[1].view(N*P,68)
        videoProcessed = self.videoBranch(videoData).view(N,P,self.NUM_VID_FEATURES) # will output a (n x partitions)x 32 tensor
        audioProcessed = self.audioBranch(audioData).view(N,P,self.NUM_AUDIO_FEATURES)# will output a (n x partitions)x 128 tensor
        x = torch.cat((videoProcessed, audioProcessed), 2).type(gpu_dtype) #(N,10,160)
        h0 = Variable(torch.zeros(1, N, self.NUM_LSTM_HIDDEN)).type(gpu_dtype)
        c0 = Variable(torch.zeros(1, N, self.NUM_LSTM_HIDDEN)).type(gpu_dtype)
        x,cn = self.lstm(x, (h0, c0))
        x = x.contiguous().view(-1,128)
        x = self.fc(x)
        x = self.sigmoid(x) #(N*P,5)
        x = torch.mean(x.view(N,P,5),1).squeeze() #(N,5)    
        return x

# %% [markdown]
# ## Train output Criterian (L1 loss) and Optimizer (Adam)

# %%
train_model(startModel=None, startEpoch=0, numEpochs=5)

# %%
train_model(startModel='./resnet_for_rnn/ResNet34_LSTM_experiment/checkpoint.pth.tar', startEpoch=5, numEpochs=20)

# %%
# Plotting helper for loss
def  plotLossStats(trainingLoss, validationLoss):
    plt.plot(trainingLoss, label='trainingLoss')
    plt.plot(vaidationLoss, label='validation loss')
    plt.xlabel('iteration')
    plt.ylabel('loss')
    plt.title('Training and Validation Loss history')
    plt.show()

np.loadtxt('log_ResNet34_LSTM_experiment.txt')

# %%
a = np.loadtxt('log_ResNet34_LSTM_experiment.txt')

# %%
def imshow(inp, title=None):
    """Imshow for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)  # pause a bit so that plots are updated


show_imgsamples,show_audiosamle,show_labelsample = next(iter(dset_loaders['val']))


show_unflattened_sample = show_imgsamples.view(-1,3,256,256)
# Make a grid from batch
plt.figure( figsize=(10, 16))
out = torchvision.utils.make_grid(show_unflattened_sample,nrow=10)
imshow(out, title='show sample')
#plt.savefig('train_exp.png', bbox_inches='tight')

# %%
#show_imgsamples,show_audiosamle,show_labelsample
model = AudioVisualLSTM()
checkpoint = torch.load('./resnet_for_rnn/ResNet34_LSTM_experiment/checkpoint.pth.tar')
model.load_state_dict(checkpoint['state_dict'])
        
input_image_var, input_audio_var = Variable(show_imgsamples.type(gpu_dtype)), \
Variable(show_audiosamle.type(gpu_dtype))
output = model([input_image_var,input_audio_var])
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-44-023e87fa3024> in <module>()
#       5
#       6 input_image_var, input_audio_var = Variable(show_imgsamples.type(gpu_dtype)), Variable(show_audiosamle.type(gpu_dtype))
# ----> 7 output = model([input_image_var,input_audio_var])
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# <ipython-input-42-92846a7ae188> in forward(self, x)
#      38         videoData = x[0].view(N*P,3,256,256)
#      39         audioData = x[1].view(N*P,68)
# ---> 40         videoProcessed = self.videoBranch(videoData).view(N,P,self.NUM_VID_FEATURES) # will output a (n x partitions)x 32 tensor
#      41         audioProcessed = self.audioBranch(audioData).view(N,P,self.NUM_AUDIO_FEATURES)# will output a (n x partitions)x 128 tensor
#      42         x = torch.cat((videoProcessed, audioProcessed), 2).type(gpu_dtype) #(N,10,160)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torchvision/models/resnet.py in forward(self, x)
#     137
#     138     def forward(self, x):
# --> 139         x = self.conv1(x)
#     140         x = self.bn1(x)
#     141         x = self.relu(x)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     204
#     205     def __call__(self, *input, **kwargs):
# --> 206         result = self.forward(*input, **kwargs)
#     207         for hook in self._forward_hooks.values():
#     208             hook_result = hook(self, input, result)
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     235     def forward(self, input):
#     236         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 237                         self.padding, self.dilation, self.groups)
#     238
#     239
#
# /home/cs231n/myVE35/lib/python3.5/site-packages/torch/nn/functional.py in conv2d(input, weight, bias, stride, padding, dilation, groups)
#      37     f = ConvNd(_pair(stride), _pair(padding), _pair(dilation), False,
#      38                _pair(0), groups, torch.backends.cudnn.benchmark, torch.backends.cudnn.enabled)
# ---> 39     return f(input, weight, bias)
#      40
#      41
#
# RuntimeError: tensors are on different GPUs
